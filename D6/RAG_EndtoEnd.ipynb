# %%
# 1. Install dependencies (Colab-friendly)
# !pip install -q anthropic sentence-transformers faiss-cpu rank_bm25 groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 60.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 7.4 MB/s eta 0:00:00

# %%
# 2. Set up your Anthropic API key
import os
import getpass

try:
    from google.colab import userdata
    api_key = userdata.get('Groq1_API_KEY')
except Exception:
    api_key = None

if not api_key:
    api_key = getpass.getpass("Enter your Groq API key: ")

os.environ["Groq1_API_KEY"] = api_key
print("API key configured.")
# Out:
# API key configured.

# %%
documents = [
    {
        "id": "POL-AUTO-001",
        "text": "Auto Policy, Section 4.2 (Collision Coverage): The Company will pay for direct "
                "and accidental physical loss to your covered auto caused by collision, subject to "
                "a $500 deductible per occurrence. Coverage applies regardless of fault.",
        "source": "Auto Policy Booklet", "effective_date": "2024-01-01",
    },
    {
        "id": "POL-AUTO-002",
        "text": "Auto Policy, Section 4.5 (Rental Reimbursement): If your covered auto is out of "
                "service due to a covered collision or comprehensive loss, the Company will "
                "reimburse rental costs up to $40/day for a maximum of 30 days.",
        "source": "Auto Policy Booklet", "effective_date": "2024-01-01",
    },
    {
        "id": "POL-HOME-010",
        "text": "Homeowners Policy, Section 3.1 (Dwelling Coverage): The Company will pay to repair "
                "or replace damage to the dwelling structure caused by a covered peril, up to the "
                "policy limit shown on the declarations page.",
        "source": "Homeowners Policy Booklet", "effective_date": "2024-03-15",
    },
      {
        "id": "POL-HOME-014",
        "text": "Homeowners Policy, Section 3.6 (Water Damage Exclusion): Damage caused by flood, "
                "surface water, or sewer backup is excluded from standard coverage. Separate flood "
                "insurance must be purchased to cover these perils.",
        "source": "Homeowners Policy Booklet", "effective_date": "2024-03-15",
    },
    {
        "id": "POL-CLAIMS-003",
        "text": "Claims Handling Guideline 3: All collision claims over $10,000 must be routed to "
                "a Senior Claims Adjuster for review before settlement is authorized. Claims under "
                "$10,000 may be settled by a standard adjuster.",
        "source": "Claims Handling Guidelines", "effective_date": "2024-06-01",
    },
      {
        "id": "POL-CLAIMS-007",
        "text": "Claims Handling Guideline 7: Any claim involving a suspected total loss (repair cost "
                "exceeds 75% of actual cash value) must be escalated to the Total Loss unit within "
                "2 business days of the initial estimate.",
        "source": "Claims Handling Guidelines", "effective_date": "2024-06-01",
    },
]
print(f"Loaded {len(documents)} chunks from {len(set(d['source'] for d in documents))} source documents.")
# Out:
# Loaded 6 chunks from 3 source documents.

# %%
documents = [
    {
        "id": "POL-AUTO-001",
        "text": "Auto Policy, Section 4.2 (Collision Coverage): The Company will pay for direct "
                "and accidental physical loss to your covered auto caused by collision, subject to "
                "a $500 deductible per occurrence. Coverage applies regardless of fault.",
        "source": "Auto Policy Booklet", "effective_date": "2024-01-01",
    },
    {
        "id": "POL-AUTO-002",
        "text": "Auto Policy, Section 4.5 (Rental Reimbursement): If your covered auto is out of "
                "service due to a covered collision or comprehensive loss, the Company will "
                "reimburse rental costs up to $40/day for a maximum of 30 days.",
        "source": "Auto Policy Booklet", "effective_date": "2024-01-01",
    },
    {
        "id": "POL-HOME-010",
        "text": "Homeowners Policy, Section 3.1 (Dwelling Coverage): The Company will pay to repair "
                "or replace damage to the dwelling structure caused by a covered peril, up to the "
                "policy limit shown on the declarations page.",
        "source": "Homeowners Policy Booklet", "effective_date": "2024-03-15",
    },
      {
        "id": "POL-HOME-014",
        "text": "Homeowners Policy, Section 3.6 (Water Damage Exclusion): Damage caused by flood, "
                "surface water, or sewer backup is excluded from standard coverage. Separate flood "
                "insurance must be purchased to cover these perils.",
        "source": "Homeowners Policy Booklet", "effective_date": "2024-03-15",
    },
    {
        "id": "POL-CLAIMS-003",
        "text": "Claims Handling Guideline 3: All collision claims over $10,000 must be routed to "
                "a Senior Claims Adjuster for review before settlement is authorized. Claims under "
                "$10,000 may be settled by a standard adjuster.",
        "source": "Claims Handling Guidelines", "effective_date": "2024-06-01",
    },
      {
        "id": "POL-CLAIMS-007",
        "text": "Claims Handling Guideline 7: Any claim involving a suspected total loss (repair cost "
                "exceeds 75% of actual cash value) must be escalated to the Total Loss unit within "
                "2 business days of the initial estimate.",
        "source": "Claims Handling Guidelines", "effective_date": "2024-06-01",
    },
]
print(f"Loaded {len(documents)} chunks from {len(set(d['source'] for d in documents))} source documents.")
# Out:
# Loaded 6 chunks from 3 source documents.

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
embedder = SentenceTransformer("all-MiniLM-L6-v2")
texts = [d["text"] for d in documents]
embeddings = embedder.encode(texts, normalize_embeddings=True)
dim = embeddings.shape[1]
index = faiss.IndexFlatIP(dim)  # inner product on normalized vectors = cosine similarity
index.add(np.array(embeddings, dtype="float32"))
print(f"Indexed {index.ntotal} chunks, dimension {dim}.")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Indexed 6 chunks, dimension 384.

# %%
def vector_search(query, k=3):
    q_emb = embedder.encode([query], normalize_embeddings=True)
    scores, idxs = index.search(np.array(q_emb, dtype="float32"), k)
    return [(documents[i], float(scores[0][rank])) for rank, i in enumerate(idxs[0])]

def naive_rag_retrieve(query, k=3):
    results = vector_search(query, k=k)
    return [doc for doc, score in results]

# Try it
sample_query = "How much does the company pay for a rental car after a collision?"
for doc, score in vector_search(sample_query):
    print(f"[{score:.3f}] {doc['id']}: {doc['text'][:90]}...")
# Out:
# [0.647] POL-AUTO-002: Auto Policy, Section 4.5 (Rental Reimbursement): If your covered auto is out of service du...
# [0.617] POL-AUTO-001: Auto Policy, Section 4.2 (Collision Coverage): The Company will pay for direct and acciden...
# [0.488] POL-CLAIMS-003: Claims Handling Guideline 3: All collision claims over $10,000 must be routed to a Senior ...

# %%
from rank_bm25 import BM25Okapi

tokenized_corpus = [d["text"].lower().split() for d in documents]
bm25 = BM25Okapi(tokenized_corpus)

def hybrid_search(query, k=3, vector_weight=0.6):
    # Vector scores over the full corpus
    q_emb = embedder.encode([query], normalize_embeddings=True)
    vec_scores = (np.array(embeddings, dtype='float32') @ q_emb[0])

    # BM25 keyword scores over the full corpus
    bm25_scores = np.array(bm25.get_scores(query.lower().split()))
    if bm25_scores.max() > 0:
        bm25_scores = bm25_scores / bm25_scores.max()  # normalize to 0-1

    fused = vector_weight * vec_scores + (1 - vector_weight) * bm25_scores
    top_idx = np.argsort(-fused)[:k]
    return [(documents[i], float(fused[i])) for i in top_idx]

# Compare: an exact-number query where keyword matching should help
exact_query = "What is the threshold for escalating a claim to a Senior Claims Adjuster?"
print("-- Vector-only --")
for doc, score in vector_search(exact_query):
    print(f"[{score:.3f}] {doc['id']}")
print("\n-- Hybrid (vector + BM25) --")
for doc, score in hybrid_search(exact_query):
    print(f"[{score:.3f}] {doc['id']}")
# Out:
# -- Vector-only --
# [0.646] POL-CLAIMS-003
# [0.429] POL-CLAIMS-007
# [0.226] POL-HOME-010
#
# -- Hybrid (vector + BM25) --
# [0.788] POL-CLAIMS-003
# [0.609] POL-CLAIMS-007
# [0.301] POL-HOME-010

# %%
import groq
import os # Added import for os to access environment variables
from groq import APIStatusError # Moved import of APIStatusError here
client = groq.Groq(api_key=os.environ.get("Groq1_API_KEY"))
BLOCKED_TERMS = ["ssn", "social security number", "credit card number"]  # toy input guardrail
def input_guardrail(query: str) -> bool:
    """Return True if the query is safe to process."""
    lowered = query.lower()
    return not any(term in lowered for term in BLOCKED_TERMS)

def build_context(chunks, max_text_length=None):
    formatted_chunks = []
    for d in chunks:
        text_content = d['text']
        if max_text_length and len(text_content) > max_text_length:
            text_content = text_content[:max_text_length] + "..." # Truncate and indicate truncation
        formatted_chunks.append(f"[{d['id']}] ({d['source']}, effective {d['effective_date']})\n{text_content}")
    return "\n\n".join(formatted_chunks)

def generate_answer(query, chunks, model="groq/compound", max_context_chunk_chars=500):
    context = build_context(chunks, max_text_length=max_context_chunk_chars) # Pass max_text_length to limit chunk text
    system_prompt = (
        "You are an internal policy assistant. Answer ONLY using the provided context. "
        "If the context does not contain the answer, state 'I don't know'. "
        "If the answer is found in the context, cite the chunk ID(s) you used in square brackets, e.g. [POL-AUTO-002]."
    )
    user_prompt = f"Context:\n{context}\n\nQuestion: {query}"
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        max_tokens=400,
    )
    return response.choices[0].message.content

def rag_answer(query, k=3, use_hybrid=True):
    if not input_guardrail(query):
        return "This request was blocked by an input guardrail.", []
    chunks_scores = hybrid_search(query, k=k) if use_hybrid else vector_search(query, k=k)
    chunks = [c for c, _ in chunks_scores]
    answer = generate_answer(query, chunks)
    return answer, chunks

answer, used_chunks = rag_answer("How much does the company pay for a rental car after a collision, and for how long?")
print(answer)
print("\nRetrieved chunk IDs:", [c["id"] for c in used_chunks])
# Out:
# **Answer**
#
# The policy’s Rental Reimbursement provision states that, when your covered auto is out of service because of a covered collision (or a comprehensive loss), the Company will:
#
# - **Reimburse rental‑car costs up to $40 per day**, and
# - **Do so for a maximum of 30 days**.
#
# **Source:** Auto Policy, Section 4.5 (Rental Reimbursement) – “the Company will reimburse rental costs up to $40/day for a maximum of 30 days” [POL-AUTO-002].
#
# **Reasoning**
#
# 1. The question asks specifically about the amount the Company pays for a rental car after a collision and the duration of that coverage.
# 2. The relevant policy language is found in the Rental Reimbursement section (Section 4.5) of the auto policy.
# 3. That section directly provides the daily reimbursement limit ($40) and the overall time limit (30 days).
# 4. No other sections (e.g., collision coverage or homeowners policy) affect the rental reimbursement amount or period.
#
# Therefore, the Company will cover up to **$40 per day** for a rental vehicle, for **no more than 30 days** following a covered collision.
#
# Retrieved chunk IDs: ['POL-AUTO-001', 'POL-AUTO-002', 'POL-HOME-010']

# %%
def faithfulness_check(answer, chunks, model="groq/compound", max_context_chunk_chars=500):
    context = build_context(chunks, max_text_length=max_context_chunk_chars)
    judge_prompt = (
        "You are a strict fact-checker. Given the CONTEXT and an ANSWER, respond with only "
        "one word: FAITHFUL if every claim in the answer is directly supported by the context, "
        "or UNFAITHFUL if the answer contains any claim not supported by the context.\n\n"
        f"CONTEXT:\n{context}\n\nANSWER:\n{answer}"
    )
    response = client.chat.completions.create(
        model=model,
        max_tokens=10,
        messages=[
            {"role": "user", "content": judge_prompt}
        ],
    )
    #print(response)
    return response.choices[0].message.content.strip()
verdict = faithfulness_check(answer, used_chunks)
print(f"Faithfulness verdict: {verdict}")
# Out:
# Faithfulness verdict: FAITHFUL
#
# **Reasoning**
#
# - The answer states that the Rental Reimbursement provision covers rental‑car costs up to $40 per day for a maximum of 30 days when the covered auto is out of service due to a covered collision or comprehensive loss.
# - This claim is directly supported by the context in **[POL-AUTO-002]**, which reads: “If your covered auto is out of service due to a covered collision or comprehensive loss, the Company will reimburse rental costs up to $40/day for a maximum of 30 days.”
# - No other statements in the answer go beyond what is provided in the context. Therefore, every claim in the answer is directly supported.

# %%
import time

test_queries = [
    "What is the deductible for collision coverage?",
    "Is water damage from a flood covered under the standard homeowners policy?",
    "When must a claim be escalated to the Total Loss unit?",
    "What is the company's policy on pet insurance?",  # not in the knowledge base
    "where does Gayatri Bhat stay?"
]
for q in test_queries:
    print(f"Q: {q}")
    ans = ""
    chunks = []
    verdict = "N/A"
    try:
        ans, chunks = rag_answer(q, k=2) # Reduced k to 2 to lower token usage
        verdict = faithfulness_check(ans, chunks) # This function also now truncates context
    except APIStatusError as e:
        ans = f"Error: API call failed - {e.response.json()['error']['message']}"
        print(f"API Error for query: '{q}' - {e.response.json()['error']['message']}")
    except Exception as e:
        ans = f"Error: An unexpected error occurred - {str(e)}"
        print(f"Unexpected Error for query: '{q}' - {str(e)}")

    print(f"A: {ans}")
    print(f"Faithfulness: {verdict}")
    print(f"Sources: {[c['id'] for c in chunks]}")
    print("-" * 80)
    time.sleep(50) # Increased delay to avoid rate limits
# Out:
# Q: What is the deductible for collision coverage?
# A: The deductible for collision coverage is $500 per occurrence. 【POL-AUTO-001】
# Faithfulness: FAITHFUL
# Sources: ['POL-AUTO-001', 'POL-AUTO-002']
# --------------------------------------------------------------------------------
# Q: Is water damage from a flood covered under the standard homeowners policy?
# A: **Answer:**
# No, water damage from a flood is **not** covered under the standard homeowners policy.
#
# **Reasoning and supporting information:**
#
# - The policy’s **Section 3.6 (Water Damage Exclusion)** explicitly states that “damage caused by flood, surface water, or sewer backup is excluded from standard coverage.”
# - It further notes that “separate flood insurance must be purchased to cover these perils.”
# - Therefore, even though Section 3.1 (Dwelling Coverage) provides repair or replacement for damage caused by covered perils, flood damage does not qualify as a covered peril under the standard policy.
#
# **Citation:** [POL-HOME-014]
# Faithfulness: FAITHFUL
# Sources: ['POL-HOME-014', 'POL-HOME-010']
# --------------------------------------------------------------------------------
# Q: When must a claim be escalated to the Total Loss unit?
# A: A claim must be escalated to the Total Loss unit **within 2 business days of the initial estimate** whenever the repair cost is suspected to exceed **75 % of the vehicle’s actual cash value**. [POL-CLAIMS-007]
# Faithfulness: FAITHFUL
# Sources: ['POL-CLAIMS-007', 'POL-AUTO-001']
# --------------------------------------------------------------------------------
# Q: What is the company's policy on pet insurance?
# A: The only policy excerpts provided are for a Homeowners policy (Section 3.1 – dwelling coverage) and an Auto policy (Section 4.2 – collision coverage). Neither excerpt mentions pet insurance or any related coverage.
#
# Because the context contains no information about a pet‑insurance policy, I cannot determine the company's stance on pet insurance.
#
# **Answer:** I don't know.
# Faithfulness: FAITHFUL
# Sources: ['POL-HOME-010', 'POL-AUTO-001']
# --------------------------------------------------------------------------------
# Q: where does Gayatri Bhat stay?
# A: I don't know.
# Faithfulness: UNFAITHFUL
# Sources: ['POL-HOME-010', 'POL-HOME-014']
# --------------------------------------------------------------------------------
